# %%
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt

# %%
#index_col="title" marca como indice de las filas a la columna de titulo de titulos
df1 = pd.read_csv("datasetProyecto.csv", index_col="title")

# %%
#Renombramiento del Cabecera de índice 'title'
df1.index.name = 'Titulo'

# %%
# Delimitación del número de filas a analizar. 350 del dataset original
df1 = df1.head(350) #Por defecto .head() indica las primeras 5 filas
df1
# Out:
#                                            Unnamed: 0    year            kind  \
# Titulo
# Dinosaur Planet                                     0  2003.0  tv mini series
# Character                                           1  2021.0           movie
# Get Up and Dance!                                   2  1994.0     video movie
# The Rise and Fall of El Chapo                       3  2016.0        tv movie
# Sick - IMDb                                         4     NaN             NaN
# ...                                               ...     ...             ...
# Whisper Kill                                      345  1988.0        tv movie
# 44 Minutes: The North Hollywood Shoot-Out         346  2003.0        tv movie
# Roger & Me                                        347  1989.0           movie
# Royal Deceit                                      348  1994.0           movie
# The Wildfire Season - IMDb                        349     NaN             NaN
#
#                                                                             genre  \
# Titulo
# Dinosaur Planet                            ['Documentary', 'Animation', 'Family']
# Character                                         ['Crime', 'Horror', 'Thriller']
# Get Up and Dance!                                                      ['Family']
# The Rise and Fall of El Chapo                                     ['Documentary']
# Sick - IMDb                                                          ['Thriller']
# ...                                                                           ...
# Whisper Kill                                                ['Drama', 'Thriller']
# 44 Minutes: The North Hollywood Shoot-Out            ['Action', 'Crime', 'Drama']
# Roger & Me                                                        ['Documentary']
# Royal Deceit                                               ['Adventure', 'Drama']
# The Wildfire Season - IMDb                                              ['Drama']
#
#                                            rating     vote  \
# Titulo
# Dinosaur Planet                               7.7    474.0
# Character                                     8.3     46.0
# Get Up and Dance!                             8.1     18.0
# The Rise and Fall of El Chapo                 6.9     42.0
# Sick - IMDb                                   NaN      NaN
# ...                                           ...      ...
# Whisper Kill                                  4.9    157.0
# 44 Minutes: The North Hollywood Shoot-Out     6.3   5187.0
# Roger & Me                                    7.5  26201.0
# Royal Deceit                                  5.5   2172.0
# The Wildfire Season - IMDb                    NaN      NaN
#
#                                                                                      country  \
# Titulo
# Dinosaur Planet                                                            ['United States']
# Character                                                                          ['Japan']
# Get Up and Dance!                                                          ['United States']
# The Rise and Fall of El Chapo                                              ['United States']
# Sick - IMDb                                                                ['United States']
# ...                                                                                      ...
# Whisper Kill                                                               ['United States']
# 44 Minutes: The North Hollywood Shoot-Out                                  ['United States']
# Roger & Me                                                                 ['United States']
# Royal Deceit                               ['Netherlands', 'United Kingdom', 'Denmark', '...
# The Wildfire Season - IMDb                                                 ['United States']
#
#                                                         language  \
# Titulo
# Dinosaur Planet                                      ['English']
# Character                                           ['Japanese']
# Get Up and Dance!                                    ['English']
# The Rise and Fall of El Chapo                                NaN
# Sick - IMDb                                                  NaN
# ...                                                          ...
# Whisper Kill                                         ['English']
# 44 Minutes: The North Hollywood Shoot-Out            ['English']
# Roger & Me                                           ['English']
# Royal Deceit                               ['English', 'Danish']
# The Wildfire Season - IMDb                                   NaN
#
#                                                                                         cast  \
# Titulo
# Dinosaur Planet                                        ['Christian Slater', 'Scott Sampson']
# Character                                  ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# Get Up and Dance!                          ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# The Rise and Fall of El Chapo                                                            NaN
# Sick - IMDb                                ['Marc Menchaca', 'Gideon Adlon', 'Dylan Spray...
# ...                                                                                      ...
# Whisper Kill                               ['Loni Anderson', 'Joe Penny', 'June Lockhart'...
# 44 Minutes: The North Hollywood Shoot-Out  ['Michael Madsen', 'Ron Livingston', 'Ray Bake...
# Roger & Me                                 ['Michael Moore', 'Roger B. Smith', 'Rhonda Br...
# Royal Deceit                               ['Gabriel Byrne', 'Helen Mirren', 'Christian B...
# The Wildfire Season - IMDb                                                               NaN
#
#                                                            director  \
# Titulo
# Dinosaur Planet                                                 NaN
# Character                                           ['Akira Nagai']
# Get Up and Dance!                                 ['Steve Purcell']
# The Rise and Fall of El Chapo                                   NaN
# Sick - IMDb                                          ['John Hyams']
# ...                                                             ...
# Whisper Kill                               ['Christian I. Nyby II']
# 44 Minutes: The North Hollywood Shoot-Out         ['Yves Simoneau']
# Roger & Me                                        ['Michael Moore']
# Royal Deceit                                       ['Gabriel Axel']
# The Wildfire Season - IMDb                                      NaN
#
#                                                         composer  \
# Titulo
# Dinosaur Planet                                              NaN
# Character                                       ['Youki Kojima']
# Get Up and Dance!                                            NaN
# The Rise and Fall of El Chapo                                NaN
# Sick - IMDb                                                  NaN
# ...                                                          ...
# Whisper Kill                               ['Charles Bernstein']
# 44 Minutes: The North Hollywood Shoot-Out  ['George S. Clinton']
# Roger & Me                                                   NaN
# Royal Deceit                                    ['Per Nørgaard']
# The Wildfire Season - IMDb                                   NaN
#
#                                                                                       writer  \
# Titulo
# Dinosaur Planet                             ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']
# Character                                  ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...
# Get Up and Dance!                                                                        NaN
# The Rise and Fall of El Chapo                                                            NaN
# Sick - IMDb                                            ['Katelyn Crabb', 'Kevin Williamson']
# ...                                                                                      ...
# Whisper Kill                                                                ['John Bensink']
# 44 Minutes: The North Hollywood Shoot-Out                                   ['Tim Metcalfe']
# Roger & Me                                                                 ['Michael Moore']
# Royal Deceit                               ['Gabriel Axel', 'Erik Kjersgaard', 'Saxo Gram...
# The Wildfire Season - IMDb                                                  ['Andrew Pyper']
#
#                                            runtime
# Titulo
# Dinosaur Planet                               50.0
# Character                                    125.0
# Get Up and Dance!                             54.0
# The Rise and Fall of El Chapo                 85.0
# Sick - IMDb                                    NaN
# ...                                            ...
# Whisper Kill                                  93.0
# 44 Minutes: The North Hollywood Shoot-Out    103.0
# Roger & Me                                    91.0
# Royal Deceit                                 103.0
# The Wildfire Season - IMDb                     NaN
#
# [350 rows x 13 columns]

# %%
#Obtenemos la información del dataset (Valores nulos y no nulos)
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, Dinosaur Planet to The Wildfire Season - IMDb
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  350 non-null    int64
#  1   year        347 non-null    float64
#  2   kind        347 non-null    object
#  3   genre       348 non-null    object
#  4   rating      308 non-null    float64
#  5   vote        308 non-null    float64
#  6   country     323 non-null    object
#  7   language    317 non-null    object
#  8   cast        336 non-null    object
#  9   director    267 non-null    object
#  10  composer    186 non-null    object
#  11  writer      283 non-null    object
#  12  runtime     310 non-null    float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 38.3+ KB
# None

# %%
#Eliminación de la columna Unnamed
df1=df1.drop(columns=["Unnamed: 0"])
df1
# Out:
#                                              year            kind  \
# Titulo
# Dinosaur Planet                            2003.0  tv mini series
# Character                                  2021.0           movie
# Get Up and Dance!                          1994.0     video movie
# The Rise and Fall of El Chapo              2016.0        tv movie
# Sick - IMDb                                   NaN             NaN
# ...                                           ...             ...
# Whisper Kill                               1988.0        tv movie
# 44 Minutes: The North Hollywood Shoot-Out  2003.0        tv movie
# Roger & Me                                 1989.0           movie
# Royal Deceit                               1994.0           movie
# The Wildfire Season - IMDb                    NaN             NaN
#
#                                                                             genre  \
# Titulo
# Dinosaur Planet                            ['Documentary', 'Animation', 'Family']
# Character                                         ['Crime', 'Horror', 'Thriller']
# Get Up and Dance!                                                      ['Family']
# The Rise and Fall of El Chapo                                     ['Documentary']
# Sick - IMDb                                                          ['Thriller']
# ...                                                                           ...
# Whisper Kill                                                ['Drama', 'Thriller']
# 44 Minutes: The North Hollywood Shoot-Out            ['Action', 'Crime', 'Drama']
# Roger & Me                                                        ['Documentary']
# Royal Deceit                                               ['Adventure', 'Drama']
# The Wildfire Season - IMDb                                              ['Drama']
#
#                                            rating     vote  \
# Titulo
# Dinosaur Planet                               7.7    474.0
# Character                                     8.3     46.0
# Get Up and Dance!                             8.1     18.0
# The Rise and Fall of El Chapo                 6.9     42.0
# Sick - IMDb                                   NaN      NaN
# ...                                           ...      ...
# Whisper Kill                                  4.9    157.0
# 44 Minutes: The North Hollywood Shoot-Out     6.3   5187.0
# Roger & Me                                    7.5  26201.0
# Royal Deceit                                  5.5   2172.0
# The Wildfire Season - IMDb                    NaN      NaN
#
#                                                                                      country  \
# Titulo
# Dinosaur Planet                                                            ['United States']
# Character                                                                          ['Japan']
# Get Up and Dance!                                                          ['United States']
# The Rise and Fall of El Chapo                                              ['United States']
# Sick - IMDb                                                                ['United States']
# ...                                                                                      ...
# Whisper Kill                                                               ['United States']
# 44 Minutes: The North Hollywood Shoot-Out                                  ['United States']
# Roger & Me                                                                 ['United States']
# Royal Deceit                               ['Netherlands', 'United Kingdom', 'Denmark', '...
# The Wildfire Season - IMDb                                                 ['United States']
#
#                                                         language  \
# Titulo
# Dinosaur Planet                                      ['English']
# Character                                           ['Japanese']
# Get Up and Dance!                                    ['English']
# The Rise and Fall of El Chapo                                NaN
# Sick - IMDb                                                  NaN
# ...                                                          ...
# Whisper Kill                                         ['English']
# 44 Minutes: The North Hollywood Shoot-Out            ['English']
# Roger & Me                                           ['English']
# Royal Deceit                               ['English', 'Danish']
# The Wildfire Season - IMDb                                   NaN
#
#                                                                                         cast  \
# Titulo
# Dinosaur Planet                                        ['Christian Slater', 'Scott Sampson']
# Character                                  ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# Get Up and Dance!                          ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# The Rise and Fall of El Chapo                                                            NaN
# Sick - IMDb                                ['Marc Menchaca', 'Gideon Adlon', 'Dylan Spray...
# ...                                                                                      ...
# Whisper Kill                               ['Loni Anderson', 'Joe Penny', 'June Lockhart'...
# 44 Minutes: The North Hollywood Shoot-Out  ['Michael Madsen', 'Ron Livingston', 'Ray Bake...
# Roger & Me                                 ['Michael Moore', 'Roger B. Smith', 'Rhonda Br...
# Royal Deceit                               ['Gabriel Byrne', 'Helen Mirren', 'Christian B...
# The Wildfire Season - IMDb                                                               NaN
#
#                                                            director  \
# Titulo
# Dinosaur Planet                                                 NaN
# Character                                           ['Akira Nagai']
# Get Up and Dance!                                 ['Steve Purcell']
# The Rise and Fall of El Chapo                                   NaN
# Sick - IMDb                                          ['John Hyams']
# ...                                                             ...
# Whisper Kill                               ['Christian I. Nyby II']
# 44 Minutes: The North Hollywood Shoot-Out         ['Yves Simoneau']
# Roger & Me                                        ['Michael Moore']
# Royal Deceit                                       ['Gabriel Axel']
# The Wildfire Season - IMDb                                      NaN
#
#                                                         composer  \
# Titulo
# Dinosaur Planet                                              NaN
# Character                                       ['Youki Kojima']
# Get Up and Dance!                                            NaN
# The Rise and Fall of El Chapo                                NaN
# Sick - IMDb                                                  NaN
# ...                                                          ...
# Whisper Kill                               ['Charles Bernstein']
# 44 Minutes: The North Hollywood Shoot-Out  ['George S. Clinton']
# Roger & Me                                                   NaN
# Royal Deceit                                    ['Per Nørgaard']
# The Wildfire Season - IMDb                                   NaN
#
#                                                                                       writer  \
# Titulo
# Dinosaur Planet                             ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']
# Character                                  ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...
# Get Up and Dance!                                                                        NaN
# The Rise and Fall of El Chapo                                                            NaN
# Sick - IMDb                                            ['Katelyn Crabb', 'Kevin Williamson']
# ...                                                                                      ...
# Whisper Kill                                                                ['John Bensink']
# 44 Minutes: The North Hollywood Shoot-Out                                   ['Tim Metcalfe']
# Roger & Me                                                                 ['Michael Moore']
# Royal Deceit                               ['Gabriel Axel', 'Erik Kjersgaard', 'Saxo Gram...
# The Wildfire Season - IMDb                                                  ['Andrew Pyper']
#
#                                            runtime
# Titulo
# Dinosaur Planet                               50.0
# Character                                    125.0
# Get Up and Dance!                             54.0
# The Rise and Fall of El Chapo                 85.0
# Sick - IMDb                                    NaN
# ...                                            ...
# Whisper Kill                                  93.0
# 44 Minutes: The North Hollywood Shoot-Out    103.0
# Roger & Me                                    91.0
# Royal Deceit                                 103.0
# The Wildfire Season - IMDb                     NaN
#
# [350 rows x 12 columns]

# %%
#Renombramiento de columnas
NewCab = ['Anio', 'Tipo','Genero','Rating','Puntuacion', 'Pais Origen','Idioma','Elenco','Director','Creador','Escritor','Duracion (min)']
NewCab
cab = np.array(NewCab)
cab
# Out:
# array(['Anio', 'Tipo', 'Genero', 'Rating', 'Puntuacion', 'Pais Origen',
#        'Idioma', 'Elenco', 'Director', 'Creador', 'Escritor',
#        'Duracion (min)'], dtype='<U14')

# %%
#Renombramiento de Cabecera
df1.columns=cab
df1
# Out:
#                                              Anio            Tipo  \
# Titulo
# Dinosaur Planet                            2003.0  tv mini series
# Character                                  2021.0           movie
# Get Up and Dance!                          1994.0     video movie
# The Rise and Fall of El Chapo              2016.0        tv movie
# Sick - IMDb                                   NaN             NaN
# ...                                           ...             ...
# Whisper Kill                               1988.0        tv movie
# 44 Minutes: The North Hollywood Shoot-Out  2003.0        tv movie
# Roger & Me                                 1989.0           movie
# Royal Deceit                               1994.0           movie
# The Wildfire Season - IMDb                    NaN             NaN
#
#                                                                            Genero  \
# Titulo
# Dinosaur Planet                            ['Documentary', 'Animation', 'Family']
# Character                                         ['Crime', 'Horror', 'Thriller']
# Get Up and Dance!                                                      ['Family']
# The Rise and Fall of El Chapo                                     ['Documentary']
# Sick - IMDb                                                          ['Thriller']
# ...                                                                           ...
# Whisper Kill                                                ['Drama', 'Thriller']
# 44 Minutes: The North Hollywood Shoot-Out            ['Action', 'Crime', 'Drama']
# Roger & Me                                                        ['Documentary']
# Royal Deceit                                               ['Adventure', 'Drama']
# The Wildfire Season - IMDb                                              ['Drama']
#
#                                            Rating  Puntuacion  \
# Titulo
# Dinosaur Planet                               7.7       474.0
# Character                                     8.3        46.0
# Get Up and Dance!                             8.1        18.0
# The Rise and Fall of El Chapo                 6.9        42.0
# Sick - IMDb                                   NaN         NaN
# ...                                           ...         ...
# Whisper Kill                                  4.9       157.0
# 44 Minutes: The North Hollywood Shoot-Out     6.3      5187.0
# Roger & Me                                    7.5     26201.0
# Royal Deceit                                  5.5      2172.0
# The Wildfire Season - IMDb                    NaN         NaN
#
#                                                                                  Pais Origen  \
# Titulo
# Dinosaur Planet                                                            ['United States']
# Character                                                                          ['Japan']
# Get Up and Dance!                                                          ['United States']
# The Rise and Fall of El Chapo                                              ['United States']
# Sick - IMDb                                                                ['United States']
# ...                                                                                      ...
# Whisper Kill                                                               ['United States']
# 44 Minutes: The North Hollywood Shoot-Out                                  ['United States']
# Roger & Me                                                                 ['United States']
# Royal Deceit                               ['Netherlands', 'United Kingdom', 'Denmark', '...
# The Wildfire Season - IMDb                                                 ['United States']
#
#                                                           Idioma  \
# Titulo
# Dinosaur Planet                                      ['English']
# Character                                           ['Japanese']
# Get Up and Dance!                                    ['English']
# The Rise and Fall of El Chapo                                NaN
# Sick - IMDb                                                  NaN
# ...                                                          ...
# Whisper Kill                                         ['English']
# 44 Minutes: The North Hollywood Shoot-Out            ['English']
# Roger & Me                                           ['English']
# Royal Deceit                               ['English', 'Danish']
# The Wildfire Season - IMDb                                   NaN
#
#                                                                                       Elenco  \
# Titulo
# Dinosaur Planet                                        ['Christian Slater', 'Scott Sampson']
# Character                                  ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# Get Up and Dance!                          ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# The Rise and Fall of El Chapo                                                            NaN
# Sick - IMDb                                ['Marc Menchaca', 'Gideon Adlon', 'Dylan Spray...
# ...                                                                                      ...
# Whisper Kill                               ['Loni Anderson', 'Joe Penny', 'June Lockhart'...
# 44 Minutes: The North Hollywood Shoot-Out  ['Michael Madsen', 'Ron Livingston', 'Ray Bake...
# Roger & Me                                 ['Michael Moore', 'Roger B. Smith', 'Rhonda Br...
# Royal Deceit                               ['Gabriel Byrne', 'Helen Mirren', 'Christian B...
# The Wildfire Season - IMDb                                                               NaN
#
#                                                            Director  \
# Titulo
# Dinosaur Planet                                                 NaN
# Character                                           ['Akira Nagai']
# Get Up and Dance!                                 ['Steve Purcell']
# The Rise and Fall of El Chapo                                   NaN
# Sick - IMDb                                          ['John Hyams']
# ...                                                             ...
# Whisper Kill                               ['Christian I. Nyby II']
# 44 Minutes: The North Hollywood Shoot-Out         ['Yves Simoneau']
# Roger & Me                                        ['Michael Moore']
# Royal Deceit                                       ['Gabriel Axel']
# The Wildfire Season - IMDb                                      NaN
#
#                                                          Creador  \
# Titulo
# Dinosaur Planet                                              NaN
# Character                                       ['Youki Kojima']
# Get Up and Dance!                                            NaN
# The Rise and Fall of El Chapo                                NaN
# Sick - IMDb                                                  NaN
# ...                                                          ...
# Whisper Kill                               ['Charles Bernstein']
# 44 Minutes: The North Hollywood Shoot-Out  ['George S. Clinton']
# Roger & Me                                                   NaN
# Royal Deceit                                    ['Per Nørgaard']
# The Wildfire Season - IMDb                                   NaN
#
#                                                                                     Escritor  \
# Titulo
# Dinosaur Planet                             ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']
# Character                                  ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...
# Get Up and Dance!                                                                        NaN
# The Rise and Fall of El Chapo                                                            NaN
# Sick - IMDb                                            ['Katelyn Crabb', 'Kevin Williamson']
# ...                                                                                      ...
# Whisper Kill                                                                ['John Bensink']
# 44 Minutes: The North Hollywood Shoot-Out                                   ['Tim Metcalfe']
# Roger & Me                                                                 ['Michael Moore']
# Royal Deceit                               ['Gabriel Axel', 'Erik Kjersgaard', 'Saxo Gram...
# The Wildfire Season - IMDb                                                  ['Andrew Pyper']
#
#                                            Duracion (min)
# Titulo
# Dinosaur Planet                                      50.0
# Character                                           125.0
# Get Up and Dance!                                    54.0
# The Rise and Fall of El Chapo                        85.0
# Sick - IMDb                                           NaN
# ...                                                   ...
# Whisper Kill                                         93.0
# 44 Minutes: The North Hollywood Shoot-Out           103.0
# Roger & Me                                           91.0
# Royal Deceit                                        103.0
# The Wildfire Season - IMDb                            NaN
#
# [350 rows x 12 columns]

# %%
#Contabilización de celdas vacías según cabecera
df1.isna().sum().sort_values()
# Out:
# Genero              2
# Anio                3
# Tipo                3
# Elenco             14
# Pais Origen        27
# Idioma             33
# Duracion (min)     40
# Rating             42
# Puntuacion         42
# Escritor           67
# Director           83
# Creador           164
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:ylabel='Titulo'>

# %%
df1.dropna(subset=["Genero","Tipo"], inplace=True)
df1
# Out:
#                                              Anio            Tipo  \
# Titulo
# Dinosaur Planet                            2003.0  tv mini series
# Character                                  2021.0           movie
# Get Up and Dance!                          1994.0     video movie
# The Rise and Fall of El Chapo              2016.0        tv movie
# 8 Man                                      1992.0           movie
# ...                                           ...             ...
# Cause célèbre                              1987.0        tv movie
# Whisper Kill                               1988.0        tv movie
# 44 Minutes: The North Hollywood Shoot-Out  2003.0        tv movie
# Roger & Me                                 1989.0           movie
# Royal Deceit                               1994.0           movie
#
#                                                                            Genero  \
# Titulo
# Dinosaur Planet                            ['Documentary', 'Animation', 'Family']
# Character                                         ['Crime', 'Horror', 'Thriller']
# Get Up and Dance!                                                      ['Family']
# The Rise and Fall of El Chapo                                     ['Documentary']
# 8 Man                                                        ['Action', 'Sci-Fi']
# ...                                                                           ...
# Cause célèbre                                                  ['Crime', 'Drama']
# Whisper Kill                                                ['Drama', 'Thriller']
# 44 Minutes: The North Hollywood Shoot-Out            ['Action', 'Crime', 'Drama']
# Roger & Me                                                        ['Documentary']
# Royal Deceit                                               ['Adventure', 'Drama']
#
#                                            Rating  Puntuacion  \
# Titulo
# Dinosaur Planet                               7.7       474.0
# Character                                     8.3        46.0
# Get Up and Dance!                             8.1        18.0
# The Rise and Fall of El Chapo                 6.9        42.0
# 8 Man                                         5.5        93.0
# ...                                           ...         ...
# Cause célèbre                                 6.9       152.0
# Whisper Kill                                  4.9       157.0
# 44 Minutes: The North Hollywood Shoot-Out     6.3      5187.0
# Roger & Me                                    7.5     26201.0
# Royal Deceit                                  5.5      2172.0
#
#                                                                                  Pais Origen  \
# Titulo
# Dinosaur Planet                                                            ['United States']
# Character                                                                          ['Japan']
# Get Up and Dance!                                                          ['United States']
# The Rise and Fall of El Chapo                                              ['United States']
# 8 Man                                                                              ['Japan']
# ...                                                                                      ...
# Cause célèbre                                                             ['United Kingdom']
# Whisper Kill                                                               ['United States']
# 44 Minutes: The North Hollywood Shoot-Out                                  ['United States']
# Roger & Me                                                                 ['United States']
# Royal Deceit                               ['Netherlands', 'United Kingdom', 'Denmark', '...
#
#                                                           Idioma  \
# Titulo
# Dinosaur Planet                                      ['English']
# Character                                           ['Japanese']
# Get Up and Dance!                                    ['English']
# The Rise and Fall of El Chapo                                NaN
# 8 Man                                               ['Japanese']
# ...                                                          ...
# Cause célèbre                                        ['English']
# Whisper Kill                                         ['English']
# 44 Minutes: The North Hollywood Shoot-Out            ['English']
# Roger & Me                                           ['English']
# Royal Deceit                               ['English', 'Danish']
#
#                                                                                       Elenco  \
# Titulo
# Dinosaur Planet                                        ['Christian Slater', 'Scott Sampson']
# Character                                  ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# Get Up and Dance!                          ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# The Rise and Fall of El Chapo                                                            NaN
# 8 Man                                      ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# ...                                                                                      ...
# Cause célèbre                              ['Helen Mirren', 'Harry Andrews', 'David Suche...
# Whisper Kill                               ['Loni Anderson', 'Joe Penny', 'June Lockhart'...
# 44 Minutes: The North Hollywood Shoot-Out  ['Michael Madsen', 'Ron Livingston', 'Ray Bake...
# Roger & Me                                 ['Michael Moore', 'Roger B. Smith', 'Rhonda Br...
# Royal Deceit                               ['Gabriel Byrne', 'Helen Mirren', 'Christian B...
#
#                                                            Director  \
# Titulo
# Dinosaur Planet                                                 NaN
# Character                                           ['Akira Nagai']
# Get Up and Dance!                                 ['Steve Purcell']
# The Rise and Fall of El Chapo                                   NaN
# 8 Man                                         ['Yasuhiro Horiuchi']
# ...                                                             ...
# Cause célèbre                                       ['John Gorrie']
# Whisper Kill                               ['Christian I. Nyby II']
# 44 Minutes: The North Hollywood Shoot-Out         ['Yves Simoneau']
# Roger & Me                                        ['Michael Moore']
# Royal Deceit                                       ['Gabriel Axel']
#
#                                                          Creador  \
# Titulo
# Dinosaur Planet                                              NaN
# Character                                       ['Youki Kojima']
# Get Up and Dance!                                            NaN
# The Rise and Fall of El Chapo                                NaN
# 8 Man                                            ['Carole King']
# ...                                                          ...
# Cause célèbre                                 ['Richard Harvey']
# Whisper Kill                               ['Charles Bernstein']
# 44 Minutes: The North Hollywood Shoot-Out  ['George S. Clinton']
# Roger & Me                                                   NaN
# Royal Deceit                                    ['Per Nørgaard']
#
#                                                                                     Escritor  \
# Titulo
# Dinosaur Planet                             ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']
# Character                                  ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...
# Get Up and Dance!                                                                        NaN
# The Rise and Fall of El Chapo                                                            NaN
# 8 Man                                      ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']
# ...                                                                                      ...
# Cause célèbre                                             ['Terence Rattigan', 'Ken Taylor']
# Whisper Kill                                                                ['John Bensink']
# 44 Minutes: The North Hollywood Shoot-Out                                   ['Tim Metcalfe']
# Roger & Me                                                                 ['Michael Moore']
# Royal Deceit                               ['Gabriel Axel', 'Erik Kjersgaard', 'Saxo Gram...
#
#                                            Duracion (min)
# Titulo
# Dinosaur Planet                                      50.0
# Character                                           125.0
# Get Up and Dance!                                    54.0
# The Rise and Fall of El Chapo                        85.0
# 8 Man                                                83.0
# ...                                                   ...
# Cause célèbre                                       109.0
# Whisper Kill                                         93.0
# 44 Minutes: The North Hollywood Shoot-Out           103.0
# Roger & Me                                           91.0
# Royal Deceit                                        103.0
#
# [345 rows x 12 columns]

# %%
import seaborn as sns

# %%
# vamos a modificar el valor nullo por el valor medio
# calcular la edad media x cada una de los tipos (episode, movie, tv mini series, tv movie, tv series, video movie)
"""la linea que divide la caja representa el valor medio
--"""
sns.boxplot(x='Tipo', y="Duracion (min)", data=df1)
# Out:
# <AxesSubplot:xlabel='Tipo', ylabel='Duracion (min)'>

# %%
#Eliminamos las filas que no posean datos en las columnas director, composer y writer
df1.dropna(subset=["Director", "Creador", "Escritor"], inplace=True)
df1
# Out:
#                                                       Anio      Tipo  \
# Titulo
# Character                                           2021.0     movie
# 8 Man                                               1992.0     movie
# What the #$*! Do We (K)now!?                        2004.0     movie
# Class of Nuke 'Em High Part II: Subhumanoid Mel...  1991.0     movie
# The Fighter                                         2010.0     movie
# ...                                                    ...       ...
# For the Moment                                      1993.0     movie
# Cause célèbre                                       1987.0  tv movie
# Whisper Kill                                        1988.0  tv movie
# 44 Minutes: The North Hollywood Shoot-Out           2003.0  tv movie
# Royal Deceit                                        1994.0     movie
#
#                                                                                                Genero  \
# Titulo
# Character                                                             ['Crime', 'Horror', 'Thriller']
# 8 Man                                                                            ['Action', 'Sci-Fi']
# What the #$*! Do We (K)now!?                        ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...
# Class of Nuke 'Em High Part II: Subhumanoid Mel...                     ['Comedy', 'Horror', 'Sci-Fi']
# The Fighter                                                           ['Biography', 'Drama', 'Sport']
# ...                                                                                               ...
# For the Moment                                                            ['Romance', 'War', 'Drama']
# Cause célèbre                                                                      ['Crime', 'Drama']
# Whisper Kill                                                                    ['Drama', 'Thriller']
# 44 Minutes: The North Hollywood Shoot-Out                                ['Action', 'Crime', 'Drama']
# Royal Deceit                                                                   ['Adventure', 'Drama']
#
#                                                     Rating  Puntuacion  \
# Titulo
# Character                                              8.3        46.0
# 8 Man                                                  5.5        93.0
# What the #$*! Do We (K)now!?                           5.3     13432.0
# Class of Nuke 'Em High Part II: Subhumanoid Mel...     4.5      2177.0
# The Fighter                                            7.8    351199.0
# ...                                                    ...         ...
# For the Moment                                         6.0       943.0
# Cause célèbre                                          6.9       152.0
# Whisper Kill                                           4.9       157.0
# 44 Minutes: The North Hollywood Shoot-Out              6.3      5187.0
# Royal Deceit                                           5.5      2172.0
#
#                                                                                           Pais Origen  \
# Titulo
# Character                                                                                   ['Japan']
# 8 Man                                                                                       ['Japan']
# What the #$*! Do We (K)now!?                                                        ['United States']
# Class of Nuke 'Em High Part II: Subhumanoid Mel...                                  ['United States']
# The Fighter                                                                         ['United States']
# ...                                                                                               ...
# For the Moment                                                                             ['Canada']
# Cause célèbre                                                                      ['United Kingdom']
# Whisper Kill                                                                        ['United States']
# 44 Minutes: The North Hollywood Shoot-Out                                           ['United States']
# Royal Deceit                                        ['Netherlands', 'United Kingdom', 'Denmark', '...
#
#                                                                               Idioma  \
# Titulo
# Character                                                               ['Japanese']
# 8 Man                                                                   ['Japanese']
# What the #$*! Do We (K)now!?                        ['English', 'German', 'Spanish']
# Class of Nuke 'Em High Part II: Subhumanoid Mel...                       ['English']
# The Fighter                                                              ['English']
# ...                                                                              ...
# For the Moment                                                           ['English']
# Cause célèbre                                                            ['English']
# Whisper Kill                                                             ['English']
# 44 Minutes: The North Hollywood Shoot-Out                                ['English']
# Royal Deceit                                                   ['English', 'Danish']
#
#                                                                                                Elenco  \
# Titulo
# Character                                           ['Masaki Suda', 'Fukase', 'Mitsuki Takahata', ...
# 8 Man                                               ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# What the #$*! Do We (K)now!?                        ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# Class of Nuke 'Em High Part II: Subhumanoid Mel...  ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# The Fighter                                         ['Mark Wahlberg', 'Christian Bale', 'Amy Adams...
# ...                                                                                               ...
# For the Moment                                      ['Russell Crowe', 'Christianne Hirt', 'Wanda C...
# Cause célèbre                                       ['Helen Mirren', 'Harry Andrews', 'David Suche...
# Whisper Kill                                        ['Loni Anderson', 'Joe Penny', 'June Lockhart'...
# 44 Minutes: The North Hollywood Shoot-Out           ['Michael Madsen', 'Ron Livingston', 'Ray Bake...
# Royal Deceit                                        ['Gabriel Byrne', 'Helen Mirren', 'Christian B...
#
#                                                                                              Director  \
# Titulo
# Character                                                                             ['Akira Nagai']
# 8 Man                                                                           ['Yasuhiro Horiuchi']
# What the #$*! Do We (K)now!?                        ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# Class of Nuke 'Em High Part II: Subhumanoid Mel...                                    ['Eric Louzil']
# The Fighter                                                                      ['David O. Russell']
# ...                                                                                               ...
# For the Moment                                                                 ['Aaron Kim Johnston']
# Cause célèbre                                                                         ['John Gorrie']
# Whisper Kill                                                                 ['Christian I. Nyby II']
# 44 Minutes: The North Hollywood Shoot-Out                                           ['Yves Simoneau']
# Royal Deceit                                                                         ['Gabriel Axel']
#
#                                                                    Creador  \
# Titulo
# Character                                                 ['Youki Kojima']
# 8 Man                                                      ['Carole King']
# What the #$*! Do We (K)now!?                        ['Christopher Franke']
# Class of Nuke 'Em High Part II: Subhumanoid Mel...         ['Bob Mithoff']
# The Fighter                                              ['Michael Brook']
# ...                                                                    ...
# For the Moment                                           ['Victor Davies']
# Cause célèbre                                           ['Richard Harvey']
# Whisper Kill                                         ['Charles Bernstein']
# 44 Minutes: The North Hollywood Shoot-Out            ['George S. Clinton']
# Royal Deceit                                              ['Per Nørgaard']
#
#                                                                                              Escritor  \
# Titulo
# Character                                           ['Takashi Nagasaki', 'Takashi Nagasaki', 'Anna...
# 8 Man                                               ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']
# What the #$*! Do We (K)now!?                        ['William Arntz', 'Betsy Chasse', 'Matthew Hof...
# Class of Nuke 'Em High Part II: Subhumanoid Mel...     ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']
# The Fighter                                           ['Scott Silver', 'Paul Tamasy', 'Eric Johnson']
# ...                                                                                               ...
# For the Moment                                                                 ['Aaron Kim Johnston']
# Cause célèbre                                                      ['Terence Rattigan', 'Ken Taylor']
# Whisper Kill                                                                         ['John Bensink']
# 44 Minutes: The North Hollywood Shoot-Out                                            ['Tim Metcalfe']
# Royal Deceit                                        ['Gabriel Axel', 'Erik Kjersgaard', 'Saxo Gram...
#
#                                                     Duracion (min)
# Titulo
# Character                                                    125.0
# 8 Man                                                         83.0
# What the #$*! Do We (K)now!?                                 109.0
# Class of Nuke 'Em High Part II: Subhumanoid Mel...            96.0
# The Fighter                                                  116.0
# ...                                                            ...
# For the Moment                                               120.0
# Cause célèbre                                                109.0
# Whisper Kill                                                  93.0
# 44 Minutes: The North Hollywood Shoot-Out                    103.0
# Royal Deceit                                                 103.0
#
# [173 rows x 12 columns]

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 173 entries, Character to Royal Deceit
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Año             173 non-null    float64
#  1   Tipo            173 non-null    object
#  2   Genero          173 non-null    object
#  3   Rating          171 non-null    float64
#  4   Puntuación      171 non-null    float64
#  5   País Origen     169 non-null    object
#  6   Idioma          170 non-null    object
#  7   Elenco          172 non-null    object
#  8   Director        173 non-null    object
#  9   Creador         173 non-null    object
#  10  Escritor        173 non-null    object
#  11  Duración (min)  169 non-null    float64
# dtypes: float64(4), object(8)
# memory usage: 17.6+ KB
# None

# %%
df1.to_csv('Proyecto.csv') #Para comprobar los datos en un Excel (filas con celdas vacías)
